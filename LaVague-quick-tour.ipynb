# %% [markdown]
# <div id="colab_button\">
#     <h1>LaVague: Quick-tour guide</h1>
#     <a target="_blank\" href="https://colab.research.google.com/github/lavague-ai/lavague/blob/main/docs/docs/get-started/quick-tour.ipynb">
#     <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#     </div>

# %% [markdown]
# ## Introduction
#
# LaVague is an open-source framework allowing users to leverage AI to turn natural language instructions into executable code to automate UI actions, such as filling in a form, etc.
#
# In this quick tour, we are going to show you step-by-step how can you can set-up and use LaVague to perform a few example actions on webpages. We will create and launch a Gradio demo at the end of the notebook where you can test out using LaVague interactively.
#
# > Pre-requisites: Note, if you are running the notebook locally, you will need python (test on python>=3.8) and pip installed.
#
# > Note, this notebook uses remote inference with the HuggingFace API. For local inference, see the [local quick-tour](./local-quick-tour.ipynb) (coming soon).
#
# > If you prefer to run LaVague as a Python script, you can do so by executing the `huggingface_api.py` script in the `gradio_demos` folder. However, you will still need to install the necessary webdriver for Selenium - instructions to do so are detailed in the following step.

# %% [markdown]
# ## Initial set-up

# %% [markdown]
# ### Installing driver for Selenium
#
# In this example, we will generate code using [Selenium](https://www.selenium.dev/) to perform user interface actions.
#
# Selenium requires a driver to interface with the chosen browser (Chrome, Firefox, etc.)
#
# We therefore first need to download the Chrome driver.
#
# ⚠️ For instructions on how to install a driver on a different OS, [see the Selenium documentation](https://selenium-python.readthedocs.io/installation.html#drivers)
#
# > Note that while we use Selenium for this example. We hope to integrate different automation tools such as Playwright at a later date.

# %%
# If you are missing any apt packages uncomment and run this command first:
# !sudo apt update

# !sudo apt install -y ca-certificates fonts-liberation unzip \
libappindicator3-1 libasound2 libatk-bridge2.0-0 libatk1.0-0 libc6 \
libcairo2 libcups2 libdbus-1-3 libexpat1 libfontconfig1 libgbm1 \
libgcc1 libglib2.0-0 libgtk-3-0 libnspr4 libnss3 libpango-1.0-0 \
libpangocairo-1.0-0 libstdc++6 libx11-6 libx11-xcb1 libxcb1 \
libxcomposite1 libxcursor1 libxdamage1 libxext6 libxfixes3 libxi6 \
libxrandr2 libxrender1 libxss1 libxtst6 lsb-release wget xdg-utils
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# Note, selecting 'libgcc-s1' instead of 'libgcc1'
# fonts-liberation is already the newest version (1:1.07.4-11).
# libasound2 is already the newest version (1.2.6.1-1ubuntu1).
# libasound2 set to manually installed.
# libatk-bridge2.0-0 is already the newest version (2.38.0-3).
# libatk-bridge2.0-0 set to manually installed.
# libatk1.0-0 is already the newest version (2.36.0-3build1).
# libatk1.0-0 set to manually installed.
# libcairo2 is already the newest version (1.16.0-5ubuntu2).
# libcairo2 set to manually installed.
# libfontconfig1 is already the newest version (2.13.1-4.2ubuntu5).
# libfontconfig1 set to manually installed.
# libnspr4 is already the newest version (2:4.32-3build1).
# libnspr4 set to manually installed.
# libxcb1 is already the newest version (1.14-3ubuntu3).
# libxcb1 set to manually installed.
# libxcomposite1 is already the newest version (1:0.4.5-1build2).
# libxcomposite1 set to manually installed.
# libxcursor1 is already the newest version (1:1.2.0-2build4).
# libxcursor1 set to manually installed.
# libxdamage1 is already the newest version (1:1.1.5-2build2).
# libxdamage1 set to manually installed.
# libxext6 is already the newest version (2:1.3.4-1build1).
# libxfixes3 is already the newest version (1:6.0.0-1).
# libxfixes3 set to manually installed.
# libxi6 is already the newest version (2:1.8-1build1).
# libxi6 set to manually installed.
# libxrandr2 is already the newest version (2:1.5.2-1build1).
# libxrandr2 set to manually installed.
# libxrender1 is already the newest version (1:0.9.10-1build4).
# libxrender1 set to manually installed.
# libxss1 is already the newest version (1:1.2.3-1build2).
# libxss1 set to manually installed.
# lsb-release is already the newest version (11.1.0ubuntu4).
# lsb-release set to manually installed.
# wget is already the newest version (1.21.2-2ubuntu1).
# ca-certificates is already the newest version (20230311ubuntu0.22.04.1).
# libc6 is already the newest version (2.35-0ubuntu3.6).
# libcups2 is already the newest version (2.4.1op1-1ubuntu4.8).
# libcups2 set to manually installed.
# libdbus-1-3 is already the newest version (1.12.20-2ubuntu4.1).
# libdbus-1-3 set to manually installed.
# libexpat1 is already the newest version (2.4.7-1ubuntu0.3).
# libexpat1 set to manually installed.
# libgbm1 is already the newest version (23.2.1-1ubuntu3.1~22.04.2).
# libgbm1 set to manually installed.
# libgcc-s1 is already the newest version (12.3.0-1ubuntu1~22.04).
# libglib2.0-0 is already the newest version (2.72.4-0ubuntu2.2).
# libglib2.0-0 set to manually installed.
# libgtk-3-0 is already the newest version (3.24.33-1ubuntu2).
# libgtk-3-0 set to manually installed.
# libnss3 is already the newest version (2:3.68.2-0ubuntu1.2).
# libnss3 set to manually installed.
# libpango-1.0-0 is already the newest version (1.50.6+ds-2ubuntu1).
# libpango-1.0-0 set to manually installed.
# libpangocairo-1.0-0 is already the newest version (1.50.6+ds-2ubuntu1).
# libpangocairo-1.0-0 set to manually installed.
# libstdc++6 is already the newest version (12.3.0-1ubuntu1~22.04).
# libx11-6 is already the newest version (2:1.7.5-1ubuntu0.3).
# libx11-6 set to manually installed.
# libx11-xcb1 is already the newest version (2:1.7.5-1ubuntu0.3).
# libx11-xcb1 set to manually installed.
# unzip is already the newest version (6.0-26ubuntu3.2).
# xdg-utils is already the newest version (1.1.3-4.1ubuntu3~22.04.1).
# xdg-utils set to manually installed.
# The following additional packages will be installed:
#   libdbusmenu-glib4 libdbusmenu-gtk3-4
# Suggested packages:
#   indicator-application
# The following NEW packages will be installed:
#   libappindicator3-1 libdbusmenu-glib4 libdbusmenu-gtk3-4 libxtst6
# 0 upgraded, 4 newly installed, 0 to remove and 38 not upgraded.
# Need to get 113 kB of archives.
# After this operation, 432 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 libdbusmenu-glib4 amd64 16.04.1+18.10.20180917-0ubuntu8 [45.4 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 libdbusmenu-gtk3-4 amd64 16.04.1+18.10.20180917-0ubuntu8 [31.0 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libappindicator3-1 amd64 12.10.1+20.10.20200706.1-0ubuntu1 [23.2 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxtst6 amd64 2:1.2.3-1build4 [13.4 kB]
# Fetched 113 kB in 1s (133 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 4.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package libdbusmenu-glib4:amd64.
# (Reading database ... 121752 files and directories currently installed.)
# Preparing to unpack .../libdbusmenu-glib4_16.04.1+18.10.20180917-0ubuntu8_amd64.deb ...
# Unpacking libdbusmenu-glib4:amd64 (16.04.1+18.10.20180917-0ubuntu8) ...
# Selecting previously unselected package libdbusmenu-gtk3-4:amd64.
# Preparing to unpack .../libdbusmenu-gtk3-4_16.04.1+18.10.20180917-0ubuntu8_amd64.deb ...
# Unpacking libdbusmenu-gtk3-4:amd64 (16.04.1+18.10.20180917-0ubuntu8) ...
# Selecting previously unselected package libappindicator3-1.
# Preparing to unpack .../libappindicator3-1_12.10.1+20.10.20200706.1-0ubuntu1_amd64.deb ...
# Unpacking libappindicator3-1 (12.10.1+20.10.20200706.1-0ubuntu1) ...
# Selecting previously unselected package libxtst6:amd64.
# Preparing to unpack .../libxtst6_2%3a1.2.3-1build4_amd64.deb ...
# Unpacking libxtst6:amd64 (2:1.2.3-1build4) ...
# Setting up libxtst6:amd64 (2:1.2.3-1build4) ...
# Setting up libdbusmenu-glib4:amd64 (16.04.1+18.10.20180917-0ubuntu8) ...
# Setting up libdbusmenu-gtk3-4:amd64 (16.04.1+18.10.20180917-0ubuntu8) ...
# Setting up libappindicator3-1 (12.10.1+20.10.20200706.1-0ubuntu1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.4) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link

# %%
# !wget https://storage.googleapis.com/chrome-for-testing-public/122.0.6261.94/linux64/chrome-linux64.zip
# !wget https://storage.googleapis.com/chrome-for-testing-public/122.0.6261.94/linux64/chromedriver-linux64.zip
# !unzip chrome-linux64.zip
# !unzip chromedriver-linux64.zip
# !rm chrome-linux64.zip chromedriver-linux64.zip
# Out:
# --2024-03-20 12:38:04--  https://storage.googleapis.com/chrome-for-testing-public/122.0.6261.94/linux64/chrome-linux64.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.251.2.207, 74.125.137.207, 2607:f8b0:4023:c0d::cf
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.251.2.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 149157879 (142M) [application/zip]
# Saving to: ‘chrome-linux64.zip’
#
# chrome-linux64.zip  100%[===================>] 142.25M   200MB/s    in 0.7s
#
# 2024-03-20 12:38:05 (200 MB/s) - ‘chrome-linux64.zip’ saved [149157879/149157879]
#
# --2024-03-20 12:38:05--  https://storage.googleapis.com/chrome-for-testing-public/122.0.6261.94/linux64/chromedriver-linux64.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.251.2.207, 74.125.137.207, 2607:f8b0:4023:c0d::cf
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.251.2.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8597995 (8.2M) [application/zip]
# Saving to: ‘chromedriver-linux64.zip’
#
# chromedriver-linux6 100%[===================>]   8.20M  53.3MB/s    in 0.2s
#
# 2024-03-20 12:38:05 (53.3 MB/s) - ‘chromedriver-linux64.zip’ saved [8597995/8597995]
#
# Archive:  chrome-linux64.zip
#   inflating: chrome-linux64/ABOUT
#   inflating: chrome-linux64/MEIPreload/manifest.json
#   inflating: chrome-linux64/MEIPreload/preloaded_data.pb
#   inflating: chrome-linux64/chrome
#   inflating: chrome-linux64/chrome-wrapper
#   inflating: chrome-linux64/chrome_100_percent.pak
#   inflating: chrome-linux64/chrome_200_percent.pak
#   inflating: chrome-linux64/chrome_crashpad_handler
#   inflating: chrome-linux64/chrome_sandbox
#   inflating: chrome-linux64/icudtl.dat
#   inflating: chrome-linux64/libEGL.so
#   inflating: chrome-linux64/libGLESv2.so
#   inflating: chrome-linux64/libvk_swiftshader.so
#   inflating: chrome-linux64/libvulkan.so.1
#  extracting: chrome-linux64/product_logo_48.png
#   inflating: chrome-linux64/resources.pak
#   inflating: chrome-linux64/v8_context_snapshot.bin
#   inflating: chrome-linux64/vk_swiftshader_icd.json
#   inflating: chrome-linux64/xdg-mime
#   inflating: chrome-linux64/xdg-settings
#    creating: chrome-linux64/locales/
#   inflating: chrome-linux64/locales/af.pak.info
#   inflating: chrome-linux64/locales/ja.pak
#   inflating: chrome-linux64/locales/fil.pak
#   inflating: chrome-linux64/locales/ca.pak.info
#   inflating: chrome-linux64/locales/es.pak.info
#   inflating: chrome-linux64/locales/th.pak
#   inflating: chrome-linux64/locales/en-GB.pak.info
#   inflating: chrome-linux64/locales/ro.pak
#   inflating: chrome-linux64/locales/fil.pak.info
#   inflating: chrome-linux64/locales/en-US.pak.info
#   inflating: chrome-linux64/locales/hi.pak.info
#   inflating: chrome-linux64/locales/sw.pak.info
#   inflating: chrome-linux64/locales/lv.pak.info
#   inflating: chrome-linux64/locales/sw.pak
#   inflating: chrome-linux64/locales/uk.pak
#   inflating: chrome-linux64/locales/de.pak.info
#   inflating: chrome-linux64/locales/sv.pak.info
#   inflating: chrome-linux64/locales/et.pak.info
#   inflating: chrome-linux64/locales/ko.pak
#   inflating: chrome-linux64/locales/zh-CN.pak
#   inflating: chrome-linux64/locales/bg.pak
#   inflating: chrome-linux64/locales/sl.pak.info
#   inflating: chrome-linux64/locales/id.pak.info
#   inflating: chrome-linux64/locales/pl.pak.info
#   inflating: chrome-linux64/locales/ru.pak.info
#   inflating: chrome-linux64/locales/it.pak.info
#   inflating: chrome-linux64/locales/ko.pak.info
#   inflating: chrome-linux64/locales/mr.pak.info
#   inflating: chrome-linux64/locales/mr.pak
#   inflating: chrome-linux64/locales/es.pak
#   inflating: chrome-linux64/locales/cs.pak.info
#   inflating: chrome-linux64/locales/hr.pak.info
#   inflating: chrome-linux64/locales/cs.pak
#   inflating: chrome-linux64/locales/lt.pak
#   inflating: chrome-linux64/locales/ml.pak.info
#   inflating: chrome-linux64/locales/te.pak
#   inflating: chrome-linux64/locales/ta.pak.info
#   inflating: chrome-linux64/locales/ca.pak
#   inflating: chrome-linux64/locales/gu.pak
#   inflating: chrome-linux64/locales/ar.pak
#   inflating: chrome-linux64/locales/ms.pak
#   inflating: chrome-linux64/locales/uk.pak.info
#   inflating: chrome-linux64/locales/da.pak
#   inflating: chrome-linux64/locales/nb.pak.info
#   inflating: chrome-linux64/locales/am.pak.info
#   inflating: chrome-linux64/locales/ml.pak
#   inflating: chrome-linux64/locales/ro.pak.info
#   inflating: chrome-linux64/locales/ur.pak.info
#   inflating: chrome-linux64/locales/sk.pak
#   inflating: chrome-linux64/locales/es-419.pak
#   inflating: chrome-linux64/locales/th.pak.info
#   inflating: chrome-linux64/locales/en-GB.pak
#   inflating: chrome-linux64/locales/he.pak
#   inflating: chrome-linux64/locales/ta.pak
#   inflating: chrome-linux64/locales/hu.pak.info
#   inflating: chrome-linux64/locales/lt.pak.info
#   inflating: chrome-linux64/locales/te.pak.info
#   inflating: chrome-linux64/locales/et.pak
#   inflating: chrome-linux64/locales/zh-TW.pak.info
#   inflating: chrome-linux64/locales/af.pak
#   inflating: chrome-linux64/locales/zh-TW.pak
#   inflating: chrome-linux64/locales/zh-CN.pak.info
#   inflating: chrome-linux64/locales/id.pak
#   inflating: chrome-linux64/locales/hi.pak
#   inflating: chrome-linux64/locales/ja.pak.info
#   inflating: chrome-linux64/locales/kn.pak
#   inflating: chrome-linux64/locales/bn.pak
#   inflating: chrome-linux64/locales/el.pak
#   inflating: chrome-linux64/locales/en-US.pak
#   inflating: chrome-linux64/locales/el.pak.info
#   inflating: chrome-linux64/locales/sr.pak
#   inflating: chrome-linux64/locales/fr.pak
#   inflating: chrome-linux64/locales/ar.pak.info
#   inflating: chrome-linux64/locales/de.pak
#   inflating: chrome-linux64/locales/vi.pak
#   inflating: chrome-linux64/locales/pt-BR.pak
#   inflating: chrome-linux64/locales/hu.pak
#   inflating: chrome-linux64/locales/nl.pak.info
#   inflating: chrome-linux64/locales/bg.pak.info
#   inflating: chrome-linux64/locales/gu.pak.info
#   inflating: chrome-linux64/locales/bn.pak.info
#   inflating: chrome-linux64/locales/pt-PT.pak.info
#   inflating: chrome-linux64/locales/kn.pak.info
#   inflating: chrome-linux64/locales/hr.pak
#   inflating: chrome-linux64/locales/fi.pak.info
#   inflating: chrome-linux64/locales/pt-PT.pak
#   inflating: chrome-linux64/locales/ms.pak.info
#   inflating: chrome-linux64/locales/ur.pak
#   inflating: chrome-linux64/locales/it.pak
#   inflating: chrome-linux64/locales/fr.pak.info
#   inflating: chrome-linux64/locales/pl.pak
#   inflating: chrome-linux64/locales/es-419.pak.info
#   inflating: chrome-linux64/locales/sr.pak.info
#   inflating: chrome-linux64/locales/fa.pak.info
#   inflating: chrome-linux64/locales/tr.pak
#   inflating: chrome-linux64/locales/pt-BR.pak.info
#   inflating: chrome-linux64/locales/fa.pak
#   inflating: chrome-linux64/locales/vi.pak.info
#   inflating: chrome-linux64/locales/he.pak.info
#   inflating: chrome-linux64/locales/nb.pak
#   inflating: chrome-linux64/locales/lv.pak
#   inflating: chrome-linux64/locales/nl.pak
#   inflating: chrome-linux64/locales/fi.pak
#   inflating: chrome-linux64/locales/ru.pak
#   inflating: chrome-linux64/locales/da.pak.info
#   inflating: chrome-linux64/locales/tr.pak.info
#   inflating: chrome-linux64/locales/sk.pak.info
#   inflating: chrome-linux64/locales/sl.pak
#   inflating: chrome-linux64/locales/am.pak
#   inflating: chrome-linux64/locales/sv.pak
#    creating: chrome-linux64/resources/
#    creating: chrome-linux64/resources/inspector_overlay/
#   inflating: chrome-linux64/resources/inspector_overlay/main.js
#   inflating: chrome-linux64/resources/inspector_overlay/inspector_overlay_resources.grd
# Archive:  chromedriver-linux64.zip
#   inflating: chromedriver-linux64/LICENSE.chromedriver
#   inflating: chromedriver-linux64/chromedriver

# %% [markdown]
# ### Installing LaVague
#
# We now need to download the LaVague PyPi package, which contains the `ActionEngine` module dedicated to handling all the key AI operations and the `CommandCenter` module, which orchestrates the whole workflow.

# %%
# !pip install lavague
# Out:
# Collecting lavague
#   Downloading lavague-1.0.4.post2-py3-none-any.whl (19 kB)
# Collecting llama-index==0.10.19 (from lavague)
#   Downloading llama_index-0.10.19-py3-none-any.whl (5.6 kB)
# Collecting llama-index-agent-openai==0.1.5 (from lavague)
#   Downloading llama_index_agent_openai-0.1.5-py3-none-any.whl (12 kB)
# Collecting llama-index-cli==0.1.9 (from lavague)
#   Downloading llama_index_cli-0.1.9-py3-none-any.whl (25 kB)
# Collecting llama-index-core==0.10.19 (from lavague)
#   Downloading llama_index_core-0.10.19-py3-none-any.whl (15.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.3/15.3 MB 59.4 MB/s eta 0:00:00
# Collecting llama-index-embeddings-azure-openai==0.1.5 (from lavague)
#   Downloading llama_index_embeddings_azure_openai-0.1.5-py3-none-any.whl (3.0 kB)
# Collecting llama-index-embeddings-huggingface==0.1.4 (from lavague)
#   Downloading llama_index_embeddings_huggingface-0.1.4-py3-none-any.whl (7.7 kB)
# Collecting llama-index-embeddings-openai==0.1.6 (from lavague)
#   Downloading llama_index_embeddings_openai-0.1.6-py3-none-any.whl (6.0 kB)
# Collecting llama-index-indices-managed-llama-cloud==0.1.4 (from lavague)
#   Downloading llama_index_indices_managed_llama_cloud-0.1.4-py3-none-any.whl (6.6 kB)
# Collecting llama-index-legacy==0.9.48 (from lavague)
#   Downloading llama_index_legacy-0.9.48-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 90.6 MB/s eta 0:00:00
# Collecting llama-index-llms-azure-openai==0.1.5 (from lavague)
#   Downloading llama_index_llms_azure_openai-0.1.5-py3-none-any.whl (4.5 kB)
# Collecting llama-index-llms-huggingface==0.1.4 (from lavague)
#   Downloading llama_index_llms_huggingface-0.1.4-py3-none-any.whl (7.2 kB)
# Collecting llama-index-llms-openai==0.1.9 (from lavague)
#   Downloading llama_index_llms_openai-0.1.9-py3-none-any.whl (10.0 kB)
# Collecting llama-index-multi-modal-llms-openai==0.1.4 (from lavague)
#   Downloading llama_index_multi_modal_llms_openai-0.1.4-py3-none-any.whl (5.8 kB)
# Collecting llama-index-program-openai==0.1.4 (from lavague)
#   Downloading llama_index_program_openai-0.1.4-py3-none-any.whl (4.1 kB)
# Collecting llama-index-question-gen-openai==0.1.3 (from lavague)
#   Downloading llama_index_question_gen_openai-0.1.3-py3-none-any.whl (2.9 kB)
# Collecting llama-index-readers-file==0.1.9 (from lavague)
#   Downloading llama_index_readers_file-0.1.9-py3-none-any.whl (35 kB)
# Collecting llama-index-readers-llama-parse==0.1.3 (from lavague)
#   Downloading llama_index_readers_llama_parse-0.1.3-py3-none-any.whl (2.5 kB)
# Collecting llama-index-retrievers-bm25==0.1.3 (from lavague)
#   Downloading llama_index_retrievers_bm25-0.1.3-py3-none-any.whl (2.9 kB)
# Collecting tree-sitter==0.21.0 (from lavague)
#   Downloading tree_sitter-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (496 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 496.6/496.6 kB 48.8 MB/s eta 0:00:00
# Collecting tree-sitter-languages==1.10.2 (from lavague)
#   Downloading tree_sitter_languages-1.10.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 113.7 MB/s eta 0:00:00
# Requirement already satisfied: nest-asyncio==1.6.0 in /usr/local/lib/python3.10/dist-packages (from lavague) (1.6.0)
# Collecting selenium==4.18.1 (from lavague)
#   Downloading selenium-4.18.1-py3-none-any.whl (10.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 80.5 MB/s eta 0:00:00
# Collecting google-search-results==2.4.2 (from lavague)
#   Downloading google_search_results-2.4.2.tar.gz (18 kB)
#   Preparing metadata (setup.py) ... done
# Collecting python-dotenv==1.0.1 (from lavague)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Collecting accelerate==0.28.0 (from lavague)
#   Downloading accelerate-0.28.0-py3-none-any.whl (290 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.1/290.1 kB 35.1 MB/s eta 0:00:00
# Collecting bitsandbytes==0.42.0 (from lavague)
#   Downloading bitsandbytes-0.42.0-py3-none-any.whl (105.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.0/105.0 MB 9.0 MB/s eta 0:00:00
# Collecting gradio==4.21.0 (from lavague)
#   Downloading gradio-4.21.0-py3-none-any.whl (17.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.0/17.0 MB 85.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate==0.28.0->lavague) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate==0.28.0->lavague) (24.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate==0.28.0->lavague) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate==0.28.0->lavague) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate==0.28.0->lavague) (2.2.1+cu121)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate==0.28.0->lavague) (0.20.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from accelerate==0.28.0->lavague) (0.4.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from bitsandbytes==0.42.0->lavague) (1.11.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from google-search-results==2.4.2->lavague) (2.31.0)
# Collecting aiofiles<24.0,>=22.0 (from gradio==4.21.0->lavague)
#   Downloading aiofiles-23.2.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: altair<6.0,>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from gradio==4.21.0->lavague) (4.2.2)
# Collecting fastapi (from gradio==4.21.0->lavague)
#   Downloading fastapi-0.110.0-py3-none-any.whl (92 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.1/92.1 kB 13.4 MB/s eta 0:00:00
# Collecting ffmpy (from gradio==4.21.0->lavague)
#   Downloading ffmpy-0.3.2.tar.gz (5.5 kB)
#   Preparing metadata (setup.py) ... done
# Collecting gradio-client==0.12.0 (from gradio==4.21.0->lavague)
#   Downloading gradio_client-0.12.0-py3-none-any.whl (310 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 310.7/310.7 kB 38.1 MB/s eta 0:00:00
# Collecting httpx>=0.24.1 (from gradio==4.21.0->lavague)
#   Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 11.4 MB/s eta 0:00:00
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in /usr/local/lib/python3.10/dist-packages (from gradio==4.21.0->lavague) (6.3.0)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.10/dist-packages (from gradio==4.21.0->lavague) (3.1.3)
# Requirement already satisfied: markupsafe~=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio==4.21.0->lavague) (2.1.5)
# Requirement already satisfied: matplotlib~=3.0 in /usr/local/lib/python3.10/dist-packages (from gradio==4.21.0->lavague) (3.7.1)
# Collecting orjson~=3.0 (from gradio==4.21.0->lavague)
#   Downloading orjson-3.9.15-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (138 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.5/138.5 kB 20.0 MB/s eta 0:00:00
# Requirement already satisfied: pandas<3.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from gradio==4.21.0->lavague) (1.5.3)
# Requirement already satisfied: pillow<11.0,>=8.0 in /usr/local/lib/python3.10/dist-packages (from gradio==4.21.0->lavague) (9.4.0)
# Requirement already satisfied: pydantic>=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio==4.21.0->lavague) (2.6.4)
# Collecting pydub (from gradio==4.21.0->lavague)
#   Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Collecting python-multipart>=0.0.9 (from gradio==4.21.0->lavague)
#   Downloading python_multipart-0.0.9-py3-none-any.whl (22 kB)
# Collecting ruff>=0.2.2 (from gradio==4.21.0->lavague)
#   Downloading ruff-0.3.3-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 114.0 MB/s eta 0:00:00
# Collecting semantic-version~=2.0 (from gradio==4.21.0->lavague)
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Collecting tomlkit==0.12.0 (from gradio==4.21.0->lavague)
#   Downloading tomlkit-0.12.0-py3-none-any.whl (37 kB)
# Requirement already satisfied: typer[all]<1.0,>=0.9 in /usr/local/lib/python3.10/dist-packages (from gradio==4.21.0->lavague) (0.9.0)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.10/dist-packages (from gradio==4.21.0->lavague) (4.10.0)
# Collecting uvicorn>=0.14.0 (from gradio==4.21.0->lavague)
#   Downloading uvicorn-0.29.0-py3-none-any.whl (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 9.3 MB/s eta 0:00:00
# Requirement already satisfied: SQLAlchemy[asyncio]>=1.4.49 in /usr/local/lib/python3.10/dist-packages (from llama-index-core==0.10.19->lavague) (2.0.28)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /usr/local/lib/python3.10/dist-packages (from llama-index-core==0.10.19->lavague) (3.9.3)
# Collecting dataclasses-json (from llama-index-core==0.10.19->lavague)
#   Downloading dataclasses_json-0.6.4-py3-none-any.whl (28 kB)
# Collecting deprecated>=1.2.9.3 (from llama-index-core==0.10.19->lavague)
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Collecting dirtyjson<2.0.0,>=1.0.8 (from llama-index-core==0.10.19->lavague)
#   Downloading dirtyjson-1.0.8-py3-none-any.whl (25 kB)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core==0.10.19->lavague) (2023.6.0)
# Collecting llamaindex-py-client<0.2.0,>=0.1.13 (from llama-index-core==0.10.19->lavague)
#   Downloading llamaindex_py_client-0.1.13-py3-none-any.whl (107 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.0/108.0 kB 16.7 MB/s eta 0:00:00
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core==0.10.19->lavague) (3.2.1)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in /usr/local/lib/python3.10/dist-packages (from llama-index-core==0.10.19->lavague) (3.8.1)
# Collecting openai>=1.1.0 (from llama-index-core==0.10.19->lavague)
#   Downloading openai-1.14.2-py3-none-any.whl (262 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 262.4/262.4 kB 32.8 MB/s eta 0:00:00
# Requirement already satisfied: tenacity<9.0.0,>=8.2.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core==0.10.19->lavague) (8.2.3)
# Collecting tiktoken>=0.3.3 (from llama-index-core==0.10.19->lavague)
#   Downloading tiktoken-0.6.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 98.3 MB/s eta 0:00:00
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /usr/local/lib/python3.10/dist-packages (from llama-index-core==0.10.19->lavague) (4.66.2)
# Collecting typing-inspect>=0.8.0 (from llama-index-core==0.10.19->lavague)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Requirement already satisfied: transformers<5.0.0,>=4.37.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-embeddings-huggingface==0.1.4->lavague) (4.38.2)
# Collecting azure-identity<2.0.0,>=1.15.0 (from llama-index-llms-azure-openai==0.1.5->lavague)
#   Downloading azure_identity-1.15.0-py3-none-any.whl (164 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.7/164.7 kB 23.6 MB/s eta 0:00:00
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in /usr/local/lib/python3.10/dist-packages (from llama-index-readers-file==0.1.9->lavague) (4.12.3)
# Collecting bs4<0.0.3,>=0.0.2 (from llama-index-readers-file==0.1.9->lavague)
#   Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Collecting pymupdf<2.0.0,>=1.23.21 (from llama-index-readers-file==0.1.9->lavague)
#   Downloading PyMuPDF-1.23.26-cp310-none-manylinux2014_x86_64.whl (4.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 101.5 MB/s eta 0:00:00
# Collecting pypdf<5.0.0,>=4.0.1 (from llama-index-readers-file==0.1.9->lavague)
#   Downloading pypdf-4.1.0-py3-none-any.whl (286 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 286.1/286.1 kB 35.4 MB/s eta 0:00:00
# Collecting striprtf<0.0.27,>=0.0.26 (from llama-index-readers-file==0.1.9->lavague)
#   Downloading striprtf-0.0.26-py3-none-any.whl (6.9 kB)
# Collecting llama-parse<0.4.0,>=0.3.3 (from llama-index-readers-llama-parse==0.1.3->lavague)
#   Downloading llama_parse-0.3.9-py3-none-any.whl (6.8 kB)
# Collecting rank-bm25<0.3.0,>=0.2.2 (from llama-index-retrievers-bm25==0.1.3->lavague)
#   Downloading rank_bm25-0.2.2-py3-none-any.whl (8.6 kB)
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in /usr/local/lib/python3.10/dist-packages (from selenium==4.18.1->lavague) (2.0.7)
# Collecting trio~=0.17 (from selenium==4.18.1->lavague)
#   Downloading trio-0.25.0-py3-none-any.whl (467 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 467.2/467.2 kB 53.6 MB/s eta 0:00:00
# Collecting trio-websocket~=0.9 (from selenium==4.18.1->lavague)
#   Downloading trio_websocket-0.11.1-py3-none-any.whl (17 kB)
# Requirement already satisfied: certifi>=2021.10.8 in /usr/local/lib/python3.10/dist-packages (from selenium==4.18.1->lavague) (2024.2.2)
# Collecting websockets<12.0,>=10.0 (from gradio-client==0.12.0->gradio==4.21.0->lavague)
#   Downloading websockets-11.0.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (129 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 19.0 MB/s eta 0:00:00
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.19->lavague) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.19->lavague) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.19->lavague) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.19->lavague) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.19->lavague) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.19->lavague) (4.0.3)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.10/dist-packages (from altair<6.0,>=4.2.0->gradio==4.21.0->lavague) (0.4)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.10/dist-packages (from altair<6.0,>=4.2.0->gradio==4.21.0->lavague) (4.19.2)
# Requirement already satisfied: toolz in /usr/local/lib/python3.10/dist-packages (from altair<6.0,>=4.2.0->gradio==4.21.0->lavague) (0.12.1)
# Collecting azure-core<2.0.0,>=1.23.0 (from azure-identity<2.0.0,>=1.15.0->llama-index-llms-azure-openai==0.1.5->lavague)
#   Downloading azure_core-1.30.1-py3-none-any.whl (193 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.4/193.4 kB 28.3 MB/s eta 0:00:00
# Requirement already satisfied: cryptography>=2.5 in /usr/local/lib/python3.10/dist-packages (from azure-identity<2.0.0,>=1.15.0->llama-index-llms-azure-openai==0.1.5->lavague) (42.0.5)
# Collecting msal<2.0.0,>=1.24.0 (from azure-identity<2.0.0,>=1.15.0->llama-index-llms-azure-openai==0.1.5->lavague)
#   Downloading msal-1.28.0-py3-none-any.whl (102 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.2/102.2 kB 16.9 MB/s eta 0:00:00
# Collecting msal-extensions<2.0.0,>=0.3.0 (from azure-identity<2.0.0,>=1.15.0->llama-index-llms-azure-openai==0.1.5->lavague)
#   Downloading msal_extensions-1.1.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4<5.0.0,>=4.12.3->llama-index-readers-file==0.1.9->lavague) (2.5)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.10/dist-packages (from deprecated>=1.2.9.3->llama-index-core==0.10.19->lavague) (1.14.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.24.1->gradio==4.21.0->lavague) (3.7.1)
# Collecting httpcore==1.* (from httpx>=0.24.1->gradio==4.21.0->lavague)
#   Downloading httpcore-1.0.4-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.8/77.8 kB 9.7 MB/s eta 0:00:00
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx>=0.24.1->gradio==4.21.0->lavague) (3.6)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.24.1->gradio==4.21.0->lavague) (1.3.1)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx>=0.24.1->gradio==4.21.0->lavague)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 8.5 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate==0.28.0->lavague) (3.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio==4.21.0->lavague) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio==4.21.0->lavague) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio==4.21.0->lavague) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio==4.21.0->lavague) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio==4.21.0->lavague) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio==4.21.0->lavague) (2.8.2)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.8.1->llama-index-core==0.10.19->lavague) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.8.1->llama-index-core==0.10.19->lavague) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.8.1->llama-index-core==0.10.19->lavague) (2023.12.25)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai>=1.1.0->llama-index-core==0.10.19->lavague) (1.7.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0,>=1.0->gradio==4.21.0->lavague) (2023.4)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.0->gradio==4.21.0->lavague) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.0->gradio==4.21.0->lavague) (2.16.3)
# Collecting PyMuPDFb==1.23.22 (from pymupdf<2.0.0,>=1.23.21->llama-index-readers-file==0.1.9->lavague)
#   Downloading PyMuPDFb-1.23.22-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (30.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.6/30.6 MB 19.2 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->google-search-results==2.4.2->lavague) (3.3.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core==0.10.19->lavague) (3.0.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.28.0->lavague) (1.12)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.10.0->accelerate==0.28.0->lavague)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 71.5 MB/s eta 0:00:00
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.10.0->accelerate==0.28.0->lavague)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 68.7 MB/s eta 0:00:00
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.10.0->accelerate==0.28.0->lavague)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 103.7 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.10.0->accelerate==0.28.0->lavague)
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.3 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.10.0->accelerate==0.28.0->lavague)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.5 MB/s eta 0:00:00
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.10.0->accelerate==0.28.0->lavague)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 7.6 MB/s eta 0:00:00
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.10.0->accelerate==0.28.0->lavague)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 11.9 MB/s eta 0:00:00
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.10.0->accelerate==0.28.0->lavague)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 8.4 MB/s eta 0:00:00
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.10.0->accelerate==0.28.0->lavague)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 6.4 MB/s eta 0:00:00
# Collecting nvidia-nccl-cu12==2.19.3 (from torch>=1.10.0->accelerate==0.28.0->lavague)
#   Downloading nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 7.0 MB/s eta 0:00:00
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.10.0->accelerate==0.28.0->lavague)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 13.4 MB/s eta 0:00:00
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.28.0->lavague) (2.2.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.10.0->accelerate==0.28.0->lavague)
#   Downloading nvidia_nvjitlink_cu12-12.4.99-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 58.9 MB/s eta 0:00:00
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.37.0->llama-index-embeddings-huggingface==0.1.4->lavague) (0.15.2)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium==4.18.1->lavague) (2.4.0)
# Collecting outcome (from trio~=0.17->selenium==4.18.1->lavague)
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium==4.18.1->lavague) (1.2.0)
# Collecting wsproto>=0.14 (from trio-websocket~=0.9->selenium==4.18.1->lavague)
#   Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Collecting colorama<0.5.0,>=0.4.3 (from typer[all]<1.0,>=0.9->gradio==4.21.0->lavague)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Collecting shellingham<2.0.0,>=1.3.0 (from typer[all]<1.0,>=0.9->gradio==4.21.0->lavague)
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Requirement already satisfied: rich<14.0.0,>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer[all]<1.0,>=0.9->gradio==4.21.0->lavague) (13.7.1)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect>=0.8.0->llama-index-core==0.10.19->lavague)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from urllib3[socks]<3,>=1.26->selenium==4.18.1->lavague) (1.7.1)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json->llama-index-core==0.10.19->lavague)
#   Downloading marshmallow-3.21.1-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 6.0 MB/s eta 0:00:00
# Collecting starlette<0.37.0,>=0.36.3 (from fastapi->gradio==4.21.0->lavague)
#   Downloading starlette-0.36.3-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 kB 11.6 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from azure-core<2.0.0,>=1.23.0->azure-identity<2.0.0,>=1.15.0->llama-index-llms-azure-openai==0.1.5->lavague) (1.16.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=2.5->azure-identity<2.0.0,>=1.15.0->llama-index-llms-azure-openai==0.1.5->lavague) (1.16.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==4.21.0->lavague) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==4.21.0->lavague) (0.33.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==4.21.0->lavague) (0.18.0)
# Requirement already satisfied: PyJWT[crypto]<3,>=1.0.0 in /usr/lib/python3/dist-packages (from msal<2.0.0,>=1.24.0->azure-identity<2.0.0,>=1.15.0->llama-index-llms-azure-openai==0.1.5->lavague) (2.3.0)
# Collecting portalocker<3,>=1.0 (from msal-extensions<2.0.0,>=0.3.0->azure-identity<2.0.0,>=1.15.0->llama-index-llms-azure-openai==0.1.5->lavague)
#   Downloading portalocker-2.8.2-py3-none-any.whl (17 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich<14.0.0,>=10.11.0->typer[all]<1.0,>=0.9->gradio==4.21.0->lavague) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich<14.0.0,>=10.11.0->typer[all]<1.0,>=0.9->gradio==4.21.0->lavague) (2.16.1)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate==0.28.0->lavague) (1.3.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=2.5->azure-identity<2.0.0,>=1.15.0->llama-index-llms-azure-openai==0.1.5->lavague) (2.21)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=10.11.0->typer[all]<1.0,>=0.9->gradio==4.21.0->lavague) (0.1.2)
# Building wheels for collected packages: google-search-results, ffmpy
#   Building wheel for google-search-results (setup.py) ... done
#   Created wheel for google-search-results: filename=google_search_results-2.4.2-py3-none-any.whl size=32004 sha256=463f44171e6a2df1c5e7b8475422675042c8e7ee1852b5201d0de8d4a400f297
#   Stored in directory: /root/.cache/pip/wheels/d3/b2/c3/03302d12bb44a2cdff3c9371f31b72c0c4e84b8d2285eeac53
#   Building wheel for ffmpy (setup.py) ... done
#   Created wheel for ffmpy: filename=ffmpy-0.3.2-py3-none-any.whl size=5584 sha256=680e2f6d2be29ad017d69d4eddfdea0fffdb5bfcda66ae24f8853025cd021f9a
#   Stored in directory: /root/.cache/pip/wheels/bd/65/9a/671fc6dcde07d4418df0c592f8df512b26d7a0029c2a23dd81
# Successfully built google-search-results ffmpy
# Installing collected packages: striprtf, pydub, ffmpy, dirtyjson, websockets, tree-sitter, tomlkit, shellingham, semantic-version, ruff, rank-bm25, python-multipart, python-dotenv, pypdf, PyMuPDFb, portalocker, outcome, orjson, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, mypy-extensions, marshmallow, h11, deprecated, colorama, aiofiles, wsproto, uvicorn, typing-inspect, trio, tree-sitter-languages, tiktoken, starlette, pymupdf, nvidia-cusparse-cu12, nvidia-cudnn-cu12, httpcore, google-search-results, bs4, bitsandbytes, azure-core, trio-websocket, nvidia-cusolver-cu12, httpx, fastapi, dataclasses-json, selenium, openai, msal, llamaindex-py-client, gradio-client, msal-extensions, llama-index-legacy, llama-index-core, gradio, accelerate, llama-parse, llama-index-retrievers-bm25, llama-index-readers-file, llama-index-llms-openai, llama-index-indices-managed-llama-cloud, llama-index-embeddings-openai, llama-index-embeddings-huggingface, azure-identity, llama-index-readers-llama-parse, llama-index-multi-modal-llms-openai, llama-index-llms-huggingface, llama-index-llms-azure-openai, llama-index-cli, llama-index-agent-openai, llama-index-program-openai, llama-index-embeddings-azure-openai, llama-index-question-gen-openai, llama-index, lavague
# Successfully installed PyMuPDFb-1.23.22 accelerate-0.28.0 aiofiles-23.2.1 azure-core-1.30.1 azure-identity-1.15.0 bitsandbytes-0.42.0 bs4-0.0.2 colorama-0.4.6 dataclasses-json-0.6.4 deprecated-1.2.14 dirtyjson-1.0.8 fastapi-0.110.0 ffmpy-0.3.2 google-search-results-2.4.2 gradio-4.21.0 gradio-client-0.12.0 h11-0.14.0 httpcore-1.0.4 httpx-0.27.0 lavague-1.0.4.post2 llama-index-0.10.19 llama-index-agent-openai-0.1.5 llama-index-cli-0.1.9 llama-index-core-0.10.19 llama-index-embeddings-azure-openai-0.1.5 llama-index-embeddings-huggingface-0.1.4 llama-index-embeddings-openai-0.1.6 llama-index-indices-managed-llama-cloud-0.1.4 llama-index-legacy-0.9.48 llama-index-llms-azure-openai-0.1.5 llama-index-llms-huggingface-0.1.4 llama-index-llms-openai-0.1.9 llama-index-multi-modal-llms-openai-0.1.4 llama-index-program-openai-0.1.4 llama-index-question-gen-openai-0.1.3 llama-index-readers-file-0.1.9 llama-index-readers-llama-parse-0.1.3 llama-index-retrievers-bm25-0.1.3 llama-parse-0.3.9 llamaindex-py-client-0.1.13 marshmallow-3.21.1 msal-1.28.0 msal-extensions-1.1.0 mypy-extensions-1.0.0 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.99 nvidia-nvtx-cu12-12.1.105 openai-1.14.2 orjson-3.9.15 outcome-1.3.0.post0 portalocker-2.8.2 pydub-0.25.1 pymupdf-1.23.26 pypdf-4.1.0 python-dotenv-1.0.1 python-multipart-0.0.9 rank-bm25-0.2.2 ruff-0.3.3 selenium-4.18.1 semantic-version-2.10.0 shellingham-1.5.4 starlette-0.36.3 striprtf-0.0.26 tiktoken-0.6.0 tomlkit-0.12.0 tree-sitter-0.21.0 tree-sitter-languages-1.10.2 trio-0.25.0 trio-websocket-0.11.1 typing-inspect-0.9.0 uvicorn-0.29.0 websockets-11.0.3 wsproto-1.2.0

# %% [markdown]
# ### HuggingFace set-up
#
# ⚠️ For remote inference with the Hugging Face inference api, you will need to provide a HuggingFace user access token with `read` access in the code block below!
#
# > If you don't have a HuggingFace user access token, you can get one for free by creating a HuggingFace account and following the instructions [here](https://huggingface.co/docs/hub/en/security-tokens).
#
# > Alternatively, you can run the notebook in local inference mode (the model will be downloaded and run locally instead of via an API) with our [local quick-tour](./local-quick-tour.ipynb) (coming soon).

# %%
# Add your HuggingFace Token below!
HF_TOKEN = "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"

# If you prefer, you can first set your HF_TOKEN an environment variable, or secret in a Google Colab and run this code instead
# try:
#   from google.colab import userdata
#   HF_TOKEN = userdata.get('HF_TOKEN')
# except:
#   import os
#   HF_TOKEN = os.environ["HF_TOKEN"]

# %% [markdown]
# ## Running LaVague
#
# ### Initial config
#
# Now we are ready to initialize our `CommandCenter` class with the following arguments:
#
# - An instance of `ActionEngine` with a LlamaIndex LLM, embedding model and prompt template. For this example, we will use the default HuggingFace API `LLM` (Nous-Hermes-2-Mixtral-8x7B-DPO) supplied with our HF token, the default `embedding` (bge-small-en-v1.5) and the default prompt template.
# - The path to our chrome-linux64/Chrome folder
# - The path to our chromedriver-linux64/chromedriver folder

# %%
from lavague import ActionEngine, CommandCenter
from lavague.defaults import HuggingfaceApiLLM, DefaultEmbedder
from lavague.prompts import DEFAULT_PROMPT


commandCenter = CommandCenter(
    ActionEngine(HuggingfaceApiLLM(token=HF_TOKEN), DefaultEmbedder(), DEFAULT_PROMPT),
    chromePath="chrome-linux64/chrome",
    chromedriverPath="chromedriver-linux64/chromedriver",
)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/743 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/133M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/366 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]

# %% [markdown]
# ### Launching LaVague
#
# We are now ready to launch an interactive Gradio demo which will allow us to execute natural language instructions on a site of our choice.
#
# To do this, we use the `commandCenter.run()` method, passing it the URL of the website we wish to perform actions on and three default instructions which will appear in the interactive Gradio page this will generate.

# %%
commandCenter.run(
    "https://huggingface.co",
    [
        "Click on the Datasets item on the menu, between Models and Spaces",
        "Click on the search bar 'Filter by name', type 'The Stack', and press 'Enter'",
        "Scroll by 500 pixels",
    ],
)
# Out:
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# Running on public URL: https://910e91ce4208c6b368.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://910e91ce4208c6b368.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# /usr/local/lib/python3.10/dist-packages/tree_sitter/__init__.py:36: FutureWarning: Language(path, name) is deprecated. Use Language(ptr, name) instead.
#   warn("{} is deprecated. Use {} instead.".format(old, new), FutureWarning)
# /usr/local/lib/python3.10/dist-packages/llama_index/core/indices/keyword_table/utils.py:18: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   value_counts = pd.Series(tokens).value_counts()
# /usr/local/lib/python3.10/dist-packages/llama_index/core/indices/keyword_table/utils.py:18: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   value_counts = pd.Series(tokens).value_counts()
# /usr/local/lib/python3.10/dist-packages/llama_index/core/indices/keyword_table/utils.py:18: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   value_counts = pd.Series(tokens).value_counts()
# /usr/local/lib/python3.10/dist-packages/llama_index/core/indices/keyword_table/utils.py:18: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   value_counts = pd.Series(tokens).value_counts()
# /usr/local/lib/python3.10/dist-packages/llama_index/core/indices/keyword_table/utils.py:18: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   value_counts = pd.Series(tokens).value_counts()
# /usr/local/lib/python3.10/dist-packages/llama_index/core/indices/keyword_table/utils.py:18: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   value_counts = pd.Series(tokens).value_counts()
# /usr/local/lib/python3.10/dist-packages/llama_index/core/indices/keyword_table/utils.py:18: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   value_counts = pd.Series(tokens).value_counts()
# /usr/local/lib/python3.10/dist-packages/llama_index/core/indices/keyword_table/utils.py:18: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   value_counts = pd.Series(tokens).value_counts()
# /usr/local/lib/python3.10/dist-packages/llama_index/core/indices/keyword_table/utils.py:18: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   value_counts = pd.Series(tokens).value_counts()
# /usr/local/lib/python3.10/dist-packages/tree_sitter/__init__.py:36: FutureWarning: Language(path, name) is deprecated. Use Language(ptr, name) instead.
#   warn("{} is deprecated. Use {} instead.".format(old, new), FutureWarning)
# /usr/local/lib/python3.10/dist-packages/llama_index/core/indices/keyword_table/utils.py:18: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   value_counts = pd.Series(tokens).value_counts()
# /usr/local/lib/python3.10/dist-packages/llama_index/core/indices/keyword_table/utils.py:18: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   value_counts = pd.Series(tokens).value_counts()
# /usr/local/lib/python3.10/dist-packages/llama_index/core/indices/keyword_table/utils.py:18: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   value_counts = pd.Series(tokens).value_counts()
# /usr/local/lib/python3.10/dist-packages/llama_index/core/indices/keyword_table/utils.py:18: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   value_counts = pd.Series(tokens).value_counts()
# /usr/local/lib/python3.10/dist-packages/tree_sitter/__init__.py:36: FutureWarning: Language(path, name) is deprecated. Use Language(ptr, name) instead.
#   warn("{} is deprecated. Use {} instead.".format(old, new), FutureWarning)
# /usr/local/lib/python3.10/dist-packages/llama_index/core/indices/keyword_table/utils.py:18: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   value_counts = pd.Series(tokens).value_counts()
# /usr/local/lib/python3.10/dist-packages/llama_index/core/indices/keyword_table/utils.py:18: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   value_counts = pd.Series(tokens).value_counts()
# /usr/local/lib/python3.10/dist-packages/llama_index/core/indices/keyword_table/utils.py:18: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   value_counts = pd.Series(tokens).value_counts()
# /usr/local/lib/python3.10/dist-packages/llama_index/core/indices/keyword_table/utils.py:18: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   value_counts = pd.Series(tokens).value_counts()
# /usr/local/lib/python3.10/dist-packages/tree_sitter/__init__.py:36: FutureWarning: Language(path, name) is deprecated. Use Language(ptr, name) instead.
#   warn("{} is deprecated. Use {} instead.".format(old, new), FutureWarning)
# /usr/local/lib/python3.10/dist-packages/llama_index/core/indices/keyword_table/utils.py:18: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   value_counts = pd.Series(tokens).value_counts()
# /usr/local/lib/python3.10/dist-packages/llama_index/core/indices/keyword_table/utils.py:18: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   value_counts = pd.Series(tokens).value_counts()
# /usr/local/lib/python3.10/dist-packages/llama_index/core/indices/keyword_table/utils.py:18: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   value_counts = pd.Series(tokens).value_counts()
# /usr/local/lib/python3.10/dist-packages/llama_index/core/indices/keyword_table/utils.py:18: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   value_counts = pd.Series(tokens).value_counts()
# /usr/local/lib/python3.10/dist-packages/llama_index/core/indices/keyword_table/utils.py:18: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   value_counts = pd.Series(tokens).value_counts()
# /usr/local/lib/python3.10/dist-packages/llama_index/core/indices/keyword_table/utils.py:18: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   value_counts = pd.Series(tokens).value_counts()
# /usr/local/lib/python3.10/dist-packages/llama_index/core/indices/keyword_table/utils.py:18: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   value_counts = pd.Series(tokens).value_counts()
# /usr/local/lib/python3.10/dist-packages/llama_index/core/indices/keyword_table/utils.py:18: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   value_counts = pd.Series(tokens).value_counts()
# /usr/local/lib/python3.10/dist-packages/llama_index/core/indices/keyword_table/utils.py:18: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   value_counts = pd.Series(tokens).value_counts()
# /usr/local/lib/python3.10/dist-packages/tree_sitter/__init__.py:36: FutureWarning: Language(path, name) is deprecated. Use Language(ptr, name) instead.
#   warn("{} is deprecated. Use {} instead.".format(old, new), FutureWarning)
# /usr/local/lib/python3.10/dist-packages/llama_index/core/indices/keyword_table/utils.py:18: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   value_counts = pd.Series(tokens).value_counts()
# /usr/local/lib/python3.10/dist-packages/llama_index/core/indices/keyword_table/utils.py:18: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   value_counts = pd.Series(tokens).value_counts()
# /usr/local/lib/python3.10/dist-packages/llama_index/core/indices/keyword_table/utils.py:18: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   value_counts = pd.Series(tokens).value_counts()
# /usr/local/lib/python3.10/dist-packages/llama_index/core/indices/keyword_table/utils.py:18: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   value_counts = pd.Series(tokens).value_counts()
# /usr/local/lib/python3.10/dist-packages/llama_index/core/indices/keyword_table/utils.py:18: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   value_counts = pd.Series(tokens).value_counts()
# /usr/local/lib/python3.10/dist-packages/llama_index/core/indices/keyword_table/utils.py:18: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   value_counts = pd.Series(tokens).value_counts()
# /usr/local/lib/python3.10/dist-packages/llama_index/core/indices/keyword_table/utils.py:18: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   value_counts = pd.Series(tokens).value_counts()
# /usr/local/lib/python3.10/dist-packages/llama_index/core/indices/keyword_table/utils.py:18: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   value_counts = pd.Series(tokens).value_counts()
# /usr/local/lib/python3.10/dist-packages/llama_index/core/indices/keyword_table/utils.py:18: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   value_counts = pd.Series(tokens).value_counts()
# /usr/local/lib/python3.10/dist-packages/tree_sitter/__init__.py:36: FutureWarning: Language(path, name) is deprecated. Use Language(ptr, name) instead.
#   warn("{} is deprecated. Use {} instead.".format(old, new), FutureWarning)
# /usr/local/lib/python3.10/dist-packages/llama_index/core/indices/keyword_table/utils.py:18: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   value_counts = pd.Series(tokens).value_counts()
# /usr/local/lib/python3.10/dist-packages/llama_index/core/indices/keyword_table/utils.py:18: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   value_counts = pd.Series(tokens).value_counts()
# /usr/local/lib/python3.10/dist-packages/llama_index/core/indices/keyword_table/utils.py:18: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   value_counts = pd.Series(tokens).value_counts()
# /usr/local/lib/python3.10/dist-packages/llama_index/core/indices/keyword_table/utils.py:18: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   value_counts = pd.Series(tokens).value_counts()
# /usr/local/lib/python3.10/dist-packages/llama_index/core/indices/keyword_table/utils.py:18: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   value_counts = pd.Series(tokens).value_counts()
# /usr/local/lib/python3.10/dist-packages/llama_index/core/indices/keyword_table/utils.py:18: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   value_counts = pd.Series(tokens).value_counts()
# /usr/local/lib/python3.10/dist-packages/llama_index/core/indices/keyword_table/utils.py:18: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   value_counts = pd.Series(tokens).value_counts()
# /usr/local/lib/python3.10/dist-packages/llama_index/core/indices/keyword_table/utils.py:18: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   value_counts = pd.Series(tokens).value_counts()
# /usr/local/lib/python3.10/dist-packages/llama_index/core/indices/keyword_table/utils.py:18: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   value_counts = pd.Series(tokens).value_counts()
# /usr/local/lib/python3.10/dist-packages/tree_sitter/__init__.py:36: FutureWarning: Language(path, name) is deprecated. Use Language(ptr, name) instead.
#   warn("{} is deprecated. Use {} instead.".format(old, new), FutureWarning)
# /usr/local/lib/python3.10/dist-packages/llama_index/core/indices/keyword_table/utils.py:18: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   value_counts = pd.Series(tokens).value_counts()
# /usr/local/lib/python3.10/dist-packages/llama_index/core/indices/keyword_table/utils.py:18: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   value_counts = pd.Series(tokens).value_counts()
# /usr/local/lib/python3.10/dist-packages/llama_index/core/indices/keyword_table/utils.py:18: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   value_counts = pd.Series(tokens).value_counts()
# /usr/local/lib/python3.10/dist-packages/llama_index/core/indices/keyword_table/utils.py:18: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   value_counts = pd.Series(tokens).value_counts()
# /usr/local/lib/python3.10/dist-packages/llama_index/core/indices/keyword_table/utils.py:18: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   value_counts = pd.Series(tokens).value_counts()
# /usr/local/lib/python3.10/dist-packages/llama_index/core/indices/keyword_table/utils.py:18: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   value_counts = pd.Series(tokens).value_counts()
# /usr/local/lib/python3.10/dist-packages/llama_index/core/indices/keyword_table/utils.py:18: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   value_counts = pd.Series(tokens).value_counts()
# /usr/local/lib/python3.10/dist-packages/llama_index/core/indices/keyword_table/utils.py:18: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   value_counts = pd.Series(tokens).value_counts()
# /usr/local/lib/python3.10/dist-packages/llama_index/core/indices/keyword_table/utils.py:18: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   value_counts = pd.Series(tokens).value_counts()
# Keyboard interruption in main thread... closing server.
# Killing tunnel 127.0.0.1:7860 <> https://910e91ce4208c6b368.gradio.live

# %% [markdown]
# ⚠️ You will need to interact with the generated Gradio demo to perform automated actions.
#
# First, you should by click in the URL textbox and press enter. Then, you should select your chosen default natural language instruction or write your own, and again click within the instruction textbox and press enter.
#
# At this point Selenium code in Python is generated by our LLM, which is then executed to perform the desired action on the website.
#
# The action will then be visibly executed in the visual interface and you can also check out the code LaVague executed to perform this action on the right-hand side of the Gradio page.
#
# > Note you can open the Gradio interface in your browser using the URL displayed in the cell output below.

# %% [markdown]
# That brings us to the end of this quick-tour. If you have any questions, join us on the LaVague Discord [here](https://discord.com/invite/SDxn9KpqX9).
